# %% [markdown]
# # String Graph
#
# We consider a **string graph** with 20 agents, a scenario also tested in Aragués et al.'s work.
# ![String graph](figures/StringGraph.png)
#
# In this case, the proposed method exhibits a significantly faster convergence rate compared to the original algorithm. At iteration step 2000, the estimation error of the original method is approximately **−0.0252**, while the proposed method achieves a much smaller error of **3.93×10⁻⁶**.
#
# The covergence rate below is: $\frac{1-\beta \lambda_3}{1-\beta \lambda_2}=1.0018$.

# %%
from matplotlib import pyplot as plt
from A import StringGraph
from iter_draw import iter_draw

A0 = StringGraph(20)


f1, f2 = iter_draw(A0, 2000,[-0.2, 0.4])
plt.show()
# Out:
# eigvalues:  [-5.28338323e-16  2.46233188e-02  9.78869674e-02  2.17986952e-01]
# covergence rate 1.0018360844334266
# original error 1999:  -0.02515679119130541
# proposed error 1999:  3.9319430155289326e-06
